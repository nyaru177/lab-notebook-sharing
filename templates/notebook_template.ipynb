# %% [markdown]
# # Notebook 标题
#
# - 作者：你的姓名
# - 日期：YYYY-MM-DD
# - 适用周次：Week X
# - 分类：Jupyter / NumPy / Matplotlib / Sklearn / PyTorch / NLP / CV / Git-Linux
# - 关键词：keyword1、keyword2
# - 适合读者：简要说明前置基础
#
# ## 学习目标
#
# 1. 目标一
# 2. 目标二
# 3. 目标三

# %% [markdown]
# ## 1. 背景与问题
#
# 说明这个技巧或实验要解决什么问题，为什么它和集训目标或科研实践有关。

# %%
# 集中导入依赖
import sys

print(sys.version)

# %% [markdown]
# ## 2. 最小可运行示例
#
# 用最短的代码跑通核心概念。

# %%
# TODO: 写一个最小示例
x = np.arange(5)
x

# %% [markdown]
# ## 3. 环境与依赖
#
# 写明 Python 版本、主要依赖、数据来源和运行方式。

# %% [markdown]
# ## 4. 关键解释
#
# - 解释核心 API 或数学概念。
# - 写出容易踩坑的地方。
# - 如有图表，说明图表表达了什么。

# %% [markdown]
# ## 5. 实验、练习与扩展
#
# 给读者留 1-3 个可以自己改的练习。

# %% [markdown]
# ## 6. 总结与参考
#
# - 总结一句最重要的收获。
# - 参考资料：官方文档 / 教程 / 论文 / 博客链接。
