# %% [markdown]
# # Week 6 示例：论文精读记录
#
# - 作者：共享仓库示例
# - 日期：2026-07-14
# - 来源：`暑期居家集训学习计划.md` → Week 6 → 论文精读
# - 适用周次：Week 6
# - 分类：论文阅读 / LaTeX
# - 关键词：研究问题、方法拆解、实验设计、改进方向、BibTeX
# - 运行环境：Python 3.10+（记录单元不依赖第三方库）
# - 适合读者：开始进行论文精读和学术报告的同学
#
# ## 学习目标
#
# 1. 结构化记录论文的问题、方法、实验和局限。
# 2. 为 LaTeX 阅读报告准备架构图、公式和 BibTeX 材料。
#
# > 原文 Week 6 没有独立实验代码，核心交付物是 LaTeX 论文阅读报告；这里用 Notebook 做一份结构化记录样例。

# %% [markdown]
# ## 1. 论文基本信息
#
# - 论文题目：
# - 作者与年份：
# - 会议或期刊：
# - 论文链接：
# - 研究方向：NLP / CV / 内容安全
# - 我为什么选择这篇论文：

# %%
paper_info = {
    'title': '在这里填写论文题目',
    'year': 2026,
    'direction': 'NLP / CV / 内容安全',
    'status': 'reading',
}
for key, value in paper_info.items():
    print(f'{key}: {value}')

# %% [markdown]
# ## 2. 论文方法拆解
#
# ### 研究问题
#
# 这篇论文解决了什么问题？现有方法的瓶颈是什么？
#
# ### 核心方法
#
# 用自己的话描述输入、模型模块、损失函数和输出。关键公式在正式报告中用 LaTeX 编号。
#
# ### 实验设计
#
# 记录数据集、baseline、指标、主要结果和消融实验。不要只抄表格，要解释比较是否公平。

# %%
reading_checklist = {
    '核心贡献是否能用一句话说清': False,
    '模型架构图是否已经画出': False,
    '关键公式是否理解': False,
    '至少两个改进方向': False,
    'BibTeX 条目是否整理': False,
}
for item, checked in reading_checklist.items():
    print('[x]' if checked else '[ ]', item)

# %% [markdown]
# ## 3. 批判性阅读与改进方向
#
# 1. 改进方向一：
# 2. 改进方向二：
# 3. 我认为最可能影响复现结果的因素：
#
# ## 4. 转为 LaTeX 报告前的检查
#
# - [ ] 论文架构图已用 TikZ 或截图+标注整理。
# - [ ] 参考文献已转成 BibTeX。
# - [ ] 所有关键结论都有论文页码或图表依据。
# - [ ] 可能的改进方向至少两条。
