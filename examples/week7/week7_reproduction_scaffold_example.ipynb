# %% [markdown]
# # Week 7 示例：代码复现脚手架
#
# - 作者：共享仓库示例
# - 日期：2026-07-14
# - 来源：`暑期居家集训学习计划.md` → Week 7 → 代码复现
# - 适用周次：Week 7
# - 分类：实验复现 / Jupyter
# - 关键词：baseline、随机种子、实验记录、消融实验
# - 运行环境：Python 3.10+、NumPy
# - 适合读者：已经完成论文精读、准备复现实验的同学
#
# ## 学习目标
#
# 1. 固定数据、随机种子和指标，记录可比较的 baseline。
# 2. 设计消融实验并保留结果解释。
#
# > 原文要求每个人根据 Week 6 精读的论文建立自己的主实验 Notebook；这里提供一个最小记录框架，不包含任何特定论文的实现。
#
# 实际复现时，把数据加载、模型和训练代码放入本 Notebook，把可复用模型放到同级 `models/` 目录。

# %% [markdown]
# ## 1. 实验配置
#
# 固定随机种子、数据划分和指标，保证 baseline 与消融实验可以比较。

# %%
import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

config = {
    'paper': '填写 Week 6 精读论文',
    'dataset': '填写数据集与版本',
    'metric': 'F1 / AUC / Accuracy',
    'seed': SEED,
}
config

# %% [markdown]
# ## 2. Baseline 与消融实验记录
#
# 下面只是结果记录格式示例。实际数值应来自真实运行，不能手动填成论文结果。

# %%
results = [
    {'experiment': 'paper baseline', 'f1': None, 'notes': '待复现'},
    {'experiment': 'remove one module', 'f1': None, 'notes': '至少一组消融'},
]

for row in results:
    print(row['experiment'], '| F1 =', row['f1'], '|', row['notes'])

# %% [markdown]
# ## 3. 复现结论
#
# - 与论文结果的差异：
# - 可能原因（数据、预处理、环境、超参数）：
# - 消融实验说明了什么：
# - 下一步需要检查的代码：
#
# 最终提交还包括 `models/` 中的可复用 Python 文件和 LaTeX 实验分析报告。
